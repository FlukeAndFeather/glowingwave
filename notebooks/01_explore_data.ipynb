# %% [markdown]
# # 01 - Data Exploration
#
# This notebook performs initial exploration of the dataset.
#
# **Objectives:**
# - Load and inspect the raw data
# - Examine data structure and types
# - Check for missing values
# - Generate summary statistics
# - Create initial visualizations

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import yaml
from pathlib import Path

# Import project modules
import sys
sys.path.append('..')
from src.data_utils import load_config, load_raw_data
from src.plotting import setup_plotting_style

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
# Load configuration
config = load_config('../config.yaml')
setup_plotting_style(config)

# %% [markdown]
# ## Load Data

# %%
# Load raw data
# data = load_raw_data(config['data']['paths']['raw'] + '/your_data_file.csv')
# data.head()

# %% [markdown]
# ## Data Overview

# %%
# Display shape and info
# print(f"Data shape: {data.shape}")
# data.info()

# %%
# Check for missing values
# data.isnull().sum()

# %% [markdown]
# ## Summary Statistics

# %%
# Generate summary statistics
# data.describe()

# %% [markdown]
# ## Initial Visualizations

# %%
# Add your visualizations here
# Example:
# fig, ax = plt.subplots(figsize=(10, 6))
# data['column'].hist(ax=ax)
# ax.set_xlabel('Value')
# ax.set_ylabel('Frequency')
# plt.show()

# %% [markdown]
# ## Conclusions
#
# Summarize key findings from the exploratory analysis:
# - Finding 1
# - Finding 2
# - Next steps
