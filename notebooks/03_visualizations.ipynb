# %% [markdown]
# # 03 - Visualizations
#
# This notebook creates publication-quality figures.
#
# **Objectives:**
# - Create final visualizations
# - Generate publication-ready figures
# - Save figures for reports/papers

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Import project modules
import sys
sys.path.append('..')
from src.data_utils import load_config
from src.plotting import setup_plotting_style, save_figure

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
# Load configuration and set up plotting
config = load_config('../config.yaml')
setup_plotting_style(config)

# Get figure size from config
figsize = tuple(config['plotting']['figsize'])

# %% [markdown]
# ## Load Data

# %%
# Load processed data or analysis results
# data = pd.read_csv(config['data']['paths']['processed'] + '/processed_data.csv')

# %% [markdown]
# ## Figure 1: [Title]

# %%
# Create figure 1
# fig, ax = plt.subplots(figsize=figsize)
# 
# # Add your plotting code
# 
# ax.set_xlabel('X Label', fontsize=12)
# ax.set_ylabel('Y Label', fontsize=12)
# ax.set_title('Figure 1: Title', fontsize=14)
# 
# # Save figure
# if config['plotting']['save_figures']:
#     save_figure(fig, 'figure_01', config)
# 
# plt.show()

# %% [markdown]
# ## Figure 2: [Title]

# %%
# Create figure 2
# fig, ax = plt.subplots(figsize=figsize)
# 
# # Add your plotting code
# 
# ax.set_xlabel('X Label', fontsize=12)
# ax.set_ylabel('Y Label', fontsize=12)
# ax.set_title('Figure 2: Title', fontsize=14)
# 
# # Save figure
# if config['plotting']['save_figures']:
#     save_figure(fig, 'figure_02', config)
# 
# plt.show()

# %% [markdown]
# ## Summary
#
# All figures have been generated and saved to the `figures/` directory.
