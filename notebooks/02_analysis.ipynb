# %% [markdown]
# # 02 - Data Analysis
#
# This notebook performs the main analysis.
#
# **Objectives:**
# - Load processed data
# - Perform statistical analyses
# - Test hypotheses
# - Generate analysis results

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# Import project modules
import sys
sys.path.append('..')
from src.data_utils import load_config
from src.analysis import compute_summary_statistics, statistical_test
from src.plotting import setup_plotting_style

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
# Load configuration
config = load_config('../config.yaml')
setup_plotting_style(config)

# %% [markdown]
# ## Load Processed Data

# %%
# Load processed data
# data = pd.read_csv(config['data']['paths']['processed'] + '/processed_data.csv')
# data.head()

# %% [markdown]
# ## Analysis

# %%
# Perform your analysis
# Add your analysis code here

# %% [markdown]
# ## Statistical Tests

# %%
# Perform statistical tests
# Example:
# result = statistical_test(group1, group2, test='ttest')
# print(f"p-value: {result['pvalue']:.4f}")

# %% [markdown]
# ## Results Summary
#
# Summarize the key results:
# - Result 1
# - Result 2
# - Interpretation
